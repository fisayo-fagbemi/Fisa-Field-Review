# %%
# Crossplot generation using lithologic algorithms [Python Porgramming Language] for Jaba Field, well 2. 
# Modified: 23/10/2021
# Created by: Fisayo Fagbemi

# %%
import pandas as pd
import matplotlib.pyplot as plt
import lasio

# %%
las = lasio.read("Well_B.las")

# %%
#pip install lasio

# %%
df = las.df()
df.describe()
# Out:
#                CAL           DT         RHOB          VSH          LLD  \
# count  4701.000000  5765.000000  5099.000000  4627.000000  5783.000000
# mean     10.684091   106.711312     2.041632     0.309673    49.124654
# std       0.915736    10.073077     0.141557     0.339908   141.442633
# min       9.550000    67.548700     1.520200     0.000200     1.179300
# 25%      10.010900    99.836200     1.963300     0.000200     5.339550
# 50%      10.416300   106.094100     2.062100     0.191700    11.639700
# 75%      11.030500   113.223700     2.131900     0.551950    27.088400
# max      13.831900   158.498200     2.457300     1.000000  1206.168900
#
#               NPHI           GR
# count  3842.000000  5645.000000
# mean      0.260560    65.092757
# std       0.085487    28.709408
# min       0.000000     9.241500
# 25%       0.250825    41.184200
# 50%       0.290500    57.968800
# 75%       0.320000    92.088000
# max       0.320000   177.044900

# %%
df2 = las.df().reset_index()
df2.describe()
# Out:
#               DEPT          CAL           DT         RHOB          VSH  \
# count  6181.000000  4701.000000  5765.000000  5099.000000  4627.000000
# mean   6446.000000    10.684091   106.711312     2.041632     0.309673
# std     892.222669     0.915736    10.073077     0.141557     0.339908
# min    4901.000000     9.550000    67.548700     1.520200     0.000200
# 25%    5673.500000    10.010900    99.836200     1.963300     0.000200
# 50%    6446.000000    10.416300   106.094100     2.062100     0.191700
# 75%    7218.500000    11.030500   113.223700     2.131900     0.551950
# max    7991.000000    13.831900   158.498200     2.457300     1.000000
#
#                LLD         NPHI           GR
# count  5783.000000  3842.000000  5645.000000
# mean     49.124654     0.260560    65.092757
# std     141.442633     0.085487    28.709408
# min       1.179300     0.000000     9.241500
# 25%       5.339550     0.250825    41.184200
# 50%      11.639700     0.290500    57.968800
# ...

# %%
df2 = las.df().reset_index()

# %%
las.sections.keys()
# Out:
# dict_keys(['Version', 'Well', 'Curves', 'Parameter', 'Other'])

# %%
las.sections['Version']
# Out:
# [HeaderItem(mnemonic="VERS", unit="", value="2.0", descr="CWLS LOG ASCII STANDA"),
#  HeaderItem(mnemonic="WRAP", unit="", value="NO", descr="ONE LINE PER DEPTH STE")]

# %%
las.sections['Well']
# Out:
# [HeaderItem(mnemonic="STRT", unit="ft", value="4901.0", descr="START DEPTH"),
#  HeaderItem(mnemonic="STEP", unit="ft", value="0.5", descr="STEP DEPTH"),
#  HeaderItem(mnemonic="STOP", unit="ft", value="7991.0", descr="STOP DEPTH"),
#  HeaderItem(mnemonic="NULL", unit="", value="-999.25", descr="NULL VALUE"),
#  HeaderItem(mnemonic="WELL", unit="", value="Well_B", descr="WELL"),
#  HeaderItem(mnemonic="XWELL", unit="m", value="523517", descr="X POS"),
#  HeaderItem(mnemonic="YWELL", unit="m", value="109658", descr="Y POS"),
#  HeaderItem(mnemonic="EDF", unit="", value="61.86", descr="DERICK FLOOR ELEVATI")]

# %%
las.sections['Curves']
# Out:
# [CurveItem(mnemonic="DEPT", unit="ft", value="", descr="", original_mnemonic="DEPT", data.shape=(6181,)),
#  CurveItem(mnemonic="CAL", unit="in", value="", descr="", original_mnemonic="CAL", data.shape=(6181,)),
#  CurveItem(mnemonic="DT", unit="us/ft", value="", descr="", original_mnemonic="DT", data.shape=(6181,)),
#  CurveItem(mnemonic="RHOB", unit="g/cm3", value="", descr="", original_mnemonic="RHOB", data.shape=(6181,)),
#  CurveItem(mnemonic="VSH", unit="fract", value="", descr="", original_mnemonic="VSH", data.shape=(6181,)),
#  CurveItem(mnemonic="LLD", unit="ohm.m", value="", descr="", original_mnemonic="LLD", data.shape=(6181,)),
#  CurveItem(mnemonic="NPHI", unit="fract", value="", descr="", original_mnemonic="NPHI", data.shape=(6181,)),
#  CurveItem(mnemonic="GR", unit="API", value="", descr="", original_mnemonic="GR", data.shape=(6181,))]

# %%
las.sections['Parameter']
# Out:
# []

# %%
for count, curve in enumerate(las.curves):
    print(f"Curve: {curve.mnemonic}, Units: {curve.unit}, Description: {curve.descr}")
print(f"There are a total of: {count+1} curves present within this file")
# Out:
# Curve: DEPT, Units: ft, Description:
# Curve: CAL, Units: in, Description:
# Curve: DT, Units: us/ft, Description:
# Curve: RHOB, Units: g/cm3, Description:
# Curve: VSH, Units: fract, Description:
# Curve: LLD, Units: ohm.m, Description:
# Curve: NPHI, Units: fract, Description:
# Curve: GR, Units: API, Description:
# There are a total of: 8 curves present within this file

# %%
for item in las.curves:
    print(f"{item.descr} ({item.mnemonic}): {item.value}")
# Out:
#  (DEPT):
#  (CAL):
#  (DT):
#  (RHOB):
#  (VSH):
#  (LLD):
#  (NPHI):
#  (GR):

# %%
las.sections['Other']
# Out:
# ''

# %%
df.head(240)
# Out:
#         CAL  DT    RHOB  VSH  LLD  NPHI  GR
# DEPT
# 4901.0  NaN NaN  1.5551  NaN  NaN   NaN NaN
# 4901.5  NaN NaN  1.5553  NaN  NaN   NaN NaN
# 4902.0  NaN NaN  1.5812  NaN  NaN   NaN NaN
# 4902.5  NaN NaN  1.6205  NaN  NaN   NaN NaN
# 4903.0  NaN NaN  1.6645  NaN  NaN   NaN NaN
# ...     ...  ..     ...  ...  ...   ...  ..
# 5018.5  NaN NaN  1.9421  NaN  NaN   NaN NaN
# 5019.0  NaN NaN  1.9625  NaN  NaN   NaN NaN
# 5019.5  NaN NaN  1.9951  NaN  NaN   NaN NaN
# 5020.0  NaN NaN  2.0349  NaN  NaN   NaN NaN
# 5020.5  NaN NaN  2.0619  NaN  NaN   NaN NaN
#
# [240 rows x 7 columns]

# %%
well = las.df()

# %%
well.head()
# Out:
#         CAL  DT    RHOB  VSH  LLD  NPHI  GR
# DEPT
# 4901.0  NaN NaN  1.5551  NaN  NaN   NaN NaN
# 4901.5  NaN NaN  1.5553  NaN  NaN   NaN NaN
# 4902.0  NaN NaN  1.5812  NaN  NaN   NaN NaN
# 4902.5  NaN NaN  1.6205  NaN  NaN   NaN NaN
# 4903.0  NaN NaN  1.6645  NaN  NaN   NaN NaN

# %%
plt.rcParams['figure.figsize'] = (8, 8)

# %%
plt.style.use('bmh')

plt.scatter(x = 'GR', y = 'RHOB', data = df, c ='DT', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.xlim(0, 140)

#plt.ylim(16, 28)

plt.yscale('log')
plt.semilogy();

plt.ylabel('Bulk Density (RHOB) - g/cc', fontsize=14)

plt.xlabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='Sonic - us/ft')

plt.show()

# %%
plt.style.use('bmh')

plt.scatter(x = 'GR', y = 'LLD', data = df, c ='DT', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.xlim(0, 140)

#plt.ylim(16, 28)

plt.yscale('log')
#plt.semilogy();

plt.ylabel('Resistivity (LLD) - ohm.m', fontsize=14)

plt.xlabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='Sonic - us/ft')

plt.show()

# %%
plt.style.use('bmh')

plt.scatter(x = 'GR', y = 'VSH', data = df, c ='LLD', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.xlim(0, 140)

#plt.ylim(16, 28)

plt.yscale('log')
plt.semilogy();

plt.ylabel('VSH - fract', fontsize=14)

plt.xlabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='LLD - ohm.m')

plt.show()

# %%
plt.style.use('bmh')

plt.scatter(x = 'LLD', y = 'VSH', data = df, c ='DT', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.xlim(0, 140)

#plt.ylim(16, 28)

plt.yscale('log')
plt.semilogy();

plt.ylabel('VSH - fract', fontsize=14)

plt.xlabel('LLD - Ohm.m', fontsize=14)

plt.colorbar(label='Gamma-Ray (GR) - API')


plt.show()

# %%
plt.style.use('bmh')

plt.scatter(x = 'RHOB', y = 'NPHI', data = df, c ='GR', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.xlim(0, 140)

#plt.ylim(16, 28)

plt.yscale('log')
plt.semilogy();

plt.ylabel('Bulk Density (RHOB) - g/cc', fontsize=14)

plt.xlabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='LLD - ohm.m')

plt.show()

# %%
plt.style.use('bmh')

plt.scatter(x = 'LLD', y = 'RHOB', data = df, c ='GR', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.xlim(0, 140)

#plt.ylim(16, 28)

#plt.yscale('log')
#plt.semilogy();

plt.ylabel('Bulk Density (RHOB) - g/cc', fontsize=14)

plt.xlabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='Sonic - us/ft')

plt.show()

# %%
plt.style.use('bmh')

plt.scatter(x = 'DT', y = 'RHOB', data = df, c ='GR', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.xlim(40, 150)

plt.ylim(2.8, 1.6)

#plt.yscale('log')
#plt.semilogy();

#plt.ylabel('Resistivity (LLD) - ohm.m', fontsize=14)
plt.ylabel('Bulk Density (RHOB) - g/cc', fontsize=14)
plt.xlabel('Sonic - us/ft', fontsize=14)

plt.colorbar(label='Gamma-Ray (GR) - API')

plt.show()

# %%
plt.subplot(121)

plt.style.use('bmh')

plt.scatter(x = 'DT', y = 'RHOB', data = df, c ='GR', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.xlim(40, 150)

plt.ylim(2.8, 1.6)

#plt.yscale('log')
#plt.semilogy();

#plt.ylabel('Resistivity (LLD) - ohm.m', fontsize=14)
plt.ylabel('Bulk Density (RHOB) - g/cc', fontsize=14)
plt.xlabel('Sonic - us/ft', fontsize=14)

plt.colorbar(label='Gamma-Ray (GR) - API')

plt.subplot(122)

plt.style.use('bmh')

plt.scatter(x = 'DT', y = 'RHOB', data = df, c ='GR', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.xlim(40, 150)

plt.ylim(2.8, 1.6)

plt.yscale('log')
plt.xscale('log')
#plt.yscale('log')
#plt.semilogy();

#plt.ylabel('Resistivity (LLD) - ohm.m', fontsize=14)
plt.ylabel('Bulk Density (RHOB) - g/cc', fontsize=14)
plt.xlabel('Sonic - us/ft', fontsize=14)

plt.colorbar(label='Gamma-Ray (GR) - API')

plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.6, wspace=0.2, hspace=0.3)

plt.show()

# %%
# Set las.index tp Dept
#df2 = las.df().reset_index()
#df2.describe()
#df2.head

# %%
# Perform, GR-RHOB - Depth (Normal vs Log scale)

plt.subplot(121)
plt.style.use('bmh')

plt.scatter(x = 'RHOB', y = 'GR', data = df2, c ='DEPT', vmin = 6700, vmax = 6750, cmap = 'Dark2')

plt.xlim(1.65, 2.65)
plt.ylim(0, 140)

plt.xlabel('Bulk Density (RHOB) - g/cc', fontsize=14)

plt.ylabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='Depth - ft')


plt.subplot(122)
plt.style.use('bmh')

plt.scatter(x = 'RHOB', y = 'GR', data = df2, c ='DEPT', vmin = 6700, vmax = 6750, cmap = 'Dark2')

plt.xlim(1.65, 2.65)
plt.ylim(0, 140)

#plt.xscale('log')
plt.xscale('log')
#plt.semilogy();

plt.xlabel('Bulk Density (RHOB) - g/cc', fontsize=14)

plt.ylabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='Depth - ft')
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.6, wspace=0.2, hspace=0.3)

plt.show()

# %%
# Perform, Depth-GR (Normal vs Log scale)

plt.subplot(121)
plt.style.use('bmh')

plt.scatter(x = 'DT', y = 'GR', data = df2, c ='DEPT', vmin = 6700, vmax = 6750, cmap = 'Dark2')

plt.xlim(50, 150)
plt.ylim(0, 140)

plt.xlabel('Sonic - us/ft', fontsize=14)

plt.ylabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='Depth - ft')


plt.subplot(122)
plt.style.use('bmh')

plt.scatter(x = 'DT', y = 'GR', data = df2, c ='DEPT', vmin = 6700, vmax = 6750, cmap = 'Dark2')

plt.xlim(50, 150)
plt.ylim(0, 140)

plt.xscale('log')
plt.xscale('log')
#plt.semilogy();

plt.xlabel('Sonic - us/ft', fontsize=14)

plt.ylabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='Depth - ft')
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.6, wspace=0.2, hspace=0.3)

plt.show()

# %%
#df.describe()
df2.describe()
# Out:
#               DEPT          CAL           DT         RHOB          VSH  \
# count  6181.000000  4701.000000  5765.000000  5099.000000  4627.000000
# mean   6446.000000    10.684091   106.711312     2.041632     0.309673
# std     892.222669     0.915736    10.073077     0.141557     0.339908
# min    4901.000000     9.550000    67.548700     1.520200     0.000200
# 25%    5673.500000    10.010900    99.836200     1.963300     0.000200
# 50%    6446.000000    10.416300   106.094100     2.062100     0.191700
# 75%    7218.500000    11.030500   113.223700     2.131900     0.551950
# max    7991.000000    13.831900   158.498200     2.457300     1.000000
#
#                LLD         NPHI           GR
# count  5783.000000  3842.000000  5645.000000
# mean     49.124654     0.260560    65.092757
# std     141.442633     0.085487    28.709408
# min       1.179300     0.000000     9.241500
# 25%       5.339550     0.250825    41.184200
# 50%      11.639700     0.290500    57.968800
# ...

# %%
# Perform, Depth-GR (Normal vs Log scale)

plt.subplot(121)
plt.style.use('bmh')

plt.scatter(x = 'NPHI', y = 'DT', data = df2, c ='DEPT', vmin = 6700, vmax = 6750, cmap = 'Dark2')

plt.xlim(0.1, 0.3)
plt.ylim(60, 135)

plt.ylabel('Sonic - us/ft', fontsize=14)

plt.xlabel('NPHI - frac', fontsize=14)

plt.colorbar(label='Depth - ft')

plt.subplot(122)
plt.style.use('bmh')

plt.scatter(x = 'NPHI', y = 'DT', data = df2, c ='DEPT', vmin = 6000, vmax = 6750, cmap = 'Dark2')

plt.xlim(0.1, 0.3)
plt.ylim(60, 135)

plt.xscale('log')
plt.xscale('log')
#plt.semilogy();

plt.ylabel('Sonic - us/ft', fontsize=14)

plt.xlabel('NPHI - frac', fontsize=14)

plt.colorbar(label='Depth - ft')
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.6, wspace=0.2, hspace=0.3)

plt.show()

# %%
# Perform, Sonic-GR

plt.subplot(131)
plt.style.use('bmh')

plt.scatter(x = 'DT', y = 'GR', data = df2, c ='DEPT', vmin = 6000, vmax = 6100, cmap = 'Dark2')

plt.xlim(60, 140)
plt.ylim(0, 140)

plt.xlabel('Sonic - us/ft', fontsize=14)

plt.ylabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='Depth - ft')

plt.subplot(132)
plt.style.use('bmh')

plt.scatter(x = 'DT', y = 'GR', data = df2, c ='DEPT', vmin = 6250, vmax = 6400, cmap = 'Dark2')

plt.xlim(60, 140)
plt.ylim(0, 140)

#plt.xscale('log')
#plt.xscale('log')

plt.xlabel('Sonic - us/ft', fontsize=14)

plt.ylabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='Depth - ft')

plt.subplot(133)
plt.style.use('bmh')

plt.scatter(x = 'DT', y = 'GR', data = df2, c ='DEPT', vmin = 6700, vmax = 6750, cmap = 'Dark2')

plt.xlim(60, 140)
plt.ylim(0, 140)

#plt.xscale('log')
#plt.xscale('log')

plt.xlabel('Sonic - us/ft', fontsize=14)

plt.ylabel('Gamma-Ray (GR) - API', fontsize=14)

plt.colorbar(label='Depth - ft')
plt.subplots_adjust(left=0.0, bottom=0.0, right=3.0, top=1.2, wspace=0.3, hspace=0.3)

plt.show()

# %%
# Perform, NPHI-RHOB (Normal vs Log scale)

plt.subplot(121)
plt.style.use('bmh')

plt.scatter(x = 'RHOB', y = 'NPHI', data = df2, c ='GR', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.ylim(0.13, 0.42)
plt.xlim(1.8, 3)

plt.xlabel('Bulk Density (RHOB) - g/cc', fontsize=14)

plt.ylabel('NPHI - frac', fontsize=14)

plt.colorbar(label='Gamma-Ray (GR) - API')

plt.subplot(122)
plt.style.use('bmh')

plt.scatter(y = 'RHOB', x = 'NPHI', data = df2, c ='GR', vmin = 0, vmax = 100, cmap = 'rainbow')

#plt.xlim(-0.01, 0.4)
#plt.ylim(2.4, 1.7)

plt.xscale('log')
plt.yscale('log')
#plt.semilogy();

plt.xlabel('Bulk Density (RHOB) - g/cc', fontsize=14)

plt.xlabel('NPHI - frac', fontsize=14)

plt.colorbar(label='Gamma-Ray (GR) - API')
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.6, wspace=0.2, hspace=0.3)

plt.show()

# %%
plt.scatter(x = 'NPHI', y = 'RHOB', data = df2)
plt.show()

# %%
#Set the style sheet to bmh
plt.style.use('bmh')

# Set up the scatter plot
plt.scatter(x='NPHI', y='RHOB', data=df2, c='GR', vmin=0, vmax=100, cmap='rainbow')

# Change the X and Y ranges
plt.xlim(0.15, 0.33)

# For the y axis, we need to flip by passing in the scale values in reverse order
plt.ylim(2.4, 1.6)

# Add in labels for the axes
plt.ylabel('Bulk Density (DEN) - g/cc', fontsize=14)
plt.xlabel('Neutron Porosity (NEU) - %', fontsize=14)

plt.colorbar(label='Color')

plt.show()

# %%
plt.subplot(121)

plt.style.use('bmh')

plt.scatter(y = 'DT', x = 'RHOB', data = df, c ='GR', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.ylim(40, 150)

plt.xlim(2.8, 1.6)

#plt.yscale('log')
#plt.semilogy();

#plt.ylabel('Resistivity (LLD) - ohm.m', fontsize=14)
plt.xlabel('Bulk Density (RHOB) - g/cc', fontsize=14)
plt.ylabel('Sonic - us/ft', fontsize=14)

plt.colorbar(label='Gamma-Ray (GR) - API')

plt.subplot(122)

plt.style.use('bmh')

plt.scatter(y = 'DT', x = 'RHOB', data = df, c ='GR', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.ylim(40, 150)

plt.xlim(2.8, 1.6)

plt.yscale('log')
plt.xscale('log')
#plt.yscale('log')
#plt.semilogy();

#plt.ylabel('Resistivity (LLD) - ohm.m', fontsize=14)
plt.xlabel('Bulk Density (RHOB) - g/cc', fontsize=14)
plt.ylabel('Sonic - us/ft', fontsize=14)

plt.colorbar(label='Gamma-Ray (GR) - API')

plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.6, wspace=0.2, hspace=0.3)

plt.show()

# %%
# Perform, NPHI-RHOB (Normal vs Log scale)

plt.subplot(121)
plt.style.use('bmh')

plt.scatter(y = 'RHOB', x = 'NPHI', data = df2, c ='GR', vmin = 0, vmax = 100, cmap = 'rainbow')

plt.xlim(0.13, 0.32)
plt.ylim(2.8, 1.7)

plt.ylabel('Bulk Density (RHOB) - g/cc', fontsize=14)

plt.xlabel('NPHI - frac', fontsize=14)

plt.colorbar(label='Gamma-Ray (GR) - API')

plt.subplot(122)
plt.style.use('bmh')

plt.scatter(y = 'RHOB', x = 'NPHI', data = df2, c ='GR', vmin = 0, vmax = 100, cmap = 'rainbow')

#plt.xlim(-0.01, 0.4)
#plt.ylim(2.4, 1.7)

plt.xscale('log')
plt.yscale('log')
#plt.semilogy();

plt.xlabel('Bulk Density (RHOB) - g/cc', fontsize=14)

plt.xlabel('NPHI - frac', fontsize=14)

plt.colorbar(label='Gamma-Ray (GR) - API')
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.6, wspace=0.2, hspace=0.3)

plt.show()
